# %%
import requests
from pathlib import Path
import polars as pl
from bs4 import BeautifulSoup

# %%
base_url = "http://asr-str01.regione.fvg.it/"


def request_sensors(session: requests.Session):
    url = "http://asr-str01.regione.fvg.it/PubblicazioneUOI/cercaSensori.do"
    payload = {"rete": "termometrica", "codice": "", "dataInizio": "", "dataFine": ""}
    return session.post(url, data=payload)

def add_to_downloads(session: requests.Session):
    url = base_url + "PubblicazioneUOI/aggiungiTutto.do"

# %%
with requests.Session() as s:
    response = request_sensors(s)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="© 2009 Insiel S.p.A." name="copyright">
# <meta content="Michele Tessaro" name="author"/>
# <meta content="C139 Misure idrografiche 01.02" name="WT.cg_n">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="pragma">
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content="0" http-equiv="expires"/>
# <link href="//www.regione.fvg.it/rafvg/export/sites/default/RAFVG/_config_/resp/css/bootstrap.css" rel="stylesheet"/>
# <link href="//www.regione.fvg.it/rafvg/export/sites/default/RAFVG/_config_/resp/css/bootstrap-theme.css" rel="stylesheet"/>
# ...
